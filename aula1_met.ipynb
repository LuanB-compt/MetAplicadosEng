# %% [markdown]
# # **MÉTODOS APLICADOS A ENGENHARIA (CÁLCULO)**

# %%
import sympy as sym
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # CÓDIGO:
# - RG7GJQ3N

# %% [markdown]
# # ANOTAÇÕES
# - Achar as leis que regem o nosso mundo com as equações diferenciais
# - Equações de uma variável independente são plotadas em planos
# - Equeções de duas variáveis independentes são plotadas em planos com altura
# -

# %%
sym.init_printing(pretty_print=True)
x = sym.Symbol('x')
f_linha = 3*x**2
f_primitivo = sym.integrate(f_linha, x)

# %% [markdown]
# - PLOTS

# %%
grafico_primitivo = sym.plot(f_primitivo, size=(10,5))
grafico_linha = sym.plot(f_linha, size=(10,5))

# %%
grafico_primitivo.append(grafico_linha[0])

graficos_juntos.legend = True
#graficos_juntos.ylim = [-10, 10]
graficos_juntos.show()

# %% [markdown]
# ## **EXERCÍCIOS**

# %% [markdown]
# - EX 1

# %%
sym.init_printing(pretty_print=True)
x = sym.Symbol('x')
y_linha = 3*x**2
y_primitiva = sym.integrate(y_linha, x)
y_primitiva
# Out:
#  3
# x

# %%
solucao1 = (-7,2)
plt.scatter(solucao1[0], solucao1[1])

# %% [markdown]
# - EX 2

# %%
y = (x**4)/16
y_linha = 
y
# Out:
#  4
# x
# ──
# 16
